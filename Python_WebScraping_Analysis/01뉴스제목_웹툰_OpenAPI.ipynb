# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
# BeautifulSoup import
import bs4
#Beautifulsoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 ={requests.__version__}')
print(f'bs4 버전 ={bs4.__version__}')
# Out:
# requests 버전 =2.32.3
# bs4 버전 =4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}

sid = 104
#url = 'https://news.naver.com/section/105'
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# Out:
# https://news.naver.com/section/105

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}

# requests 의 get() 함수 호출하기 
res=requests.get(url,headers=req_header)
print(res.status_code, res.ok)
print(type(res))
print(res)

# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if res.ok:
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")   
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    '''
       <div class='sa_text'> 
          <a href="https://n.news.naver.com/mnews/article/366/0001094461">
    '''
    a_tags = soup.select("div.sa_text a[href*='mnews/article'].sa_text_title")
    print(len(a_tags))
    print(type(a_tags)) #[Tag,Tag,Tag]
    for idx,a_tag in enumerate(a_tags,1):
        if a_tag.text:
            title = a_tag.text.strip() # 제목 
            link = a_tag['href'] #링크
            #print(len(title))
            print(f'{idx} {title} {link}')

else:
    print(f'Error Code = {res.status_code}')


# 응답(response)이 Error 이면 status code 출력

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }
    # requests 의 get() 함수 호출하기 
    res=requests.get(url,headers=req_header)
    print(res.status_code, res.ok)
    if res.ok:
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article'].sa_text_title")
        print(len(a_tags))
        # <a> 태그 리스트 순회하기
        for idx,a_tag in enumerate(a_tags,1):        
            if a_tag.text:
                title = a_tag.text.strip() # 제목
                link = a_tag['href'] # 링크
                #print(len(title))
                print(f'{idx} {title} {link}')
    else:
        # 응답(response)이 Error 이면 status code 출력    
        print(f'Error Code = {res.status_code}')

# %%
print_news('세계')
# Out:
# https://news.naver.com/section/104 세계 뉴스
# 200 True
# 46
# 1 "우리 회사는 언제 시행되나"…주 4일제, '이것' 포함돼야 번아웃↓ 직무만족↑ https://n.news.naver.com/mnews/article/011/0004512053
# 2 방글라데시 공군 훈련기, 학교에 추락···최소 18명 사망 https://n.news.naver.com/mnews/article/032/0003384341
# 3 日 연립여당, 참의원 과반 실패…이시바 '거취' 주목 https://n.news.naver.com/mnews/article/422/0000762178
# 4 ‘브렉시트의 대가?’… 英에 ‘유럽 무기 공동조달’ 참가비 부과 https://n.news.naver.com/mnews/article/021/0002724444
# 5 트럼프, 이란 핵시설 ‘파괴’ 부각하며 “필요하면 다시 공습” https://n.news.naver.com/mnews/article/056/0011993660
# 6 '트럼프 말렸다는' 베선트, 돌변해 파월 공격…"연준 점검해야" https://n.news.naver.com/mnews/article/008/0005225063
# 7 美정부, 마틴 루서 킹 암살 기록 전격 공개…"엡스타인 덮기냐" https://n.news.naver.com/mnews/article/421/0008384982
# 8 "150만 원 보내달라고 했는데…" 일본 여행 갔다 한 달째 실종된 20대 한국인 https://n.news.naver.com/mnews/article/055/0001277467
# 9 트럼프 엡스타인 보도 불만 소송 WSJ, 스코틀랜드 취재단에서 제외 https://n.news.naver.com/mnews/article/003/0013376470
# 10 韓, 국제수학올림피아드 금 4, 은 2 전원 수상 https://n.news.naver.com/mnews/article/029/0002969979
# 11 中 최신 스텔스 J-35, 실전 배치 임박 사진 확산 https://n.news.naver.com/mnews/article/011/0004512145
# 12 “전투기 보좌하는 AI 드론”…美 ‘발키리’, 독일군도 쓴다 https://n.news.naver.com/mnews/article/081/0003559871
# 39 중국 YMTC "100% 중국산 반도체 장비로 공장 짓는다" https://n.news.naver.com/mnews/article/008/0005225169
# 40 美150개 기업 암호화폐 매집, 비트는 물론 솔라나까지(종합) https://n.news.naver.com/mnews/article/421/0008385079
# 41 '캘리포니아의 상징' 인앤아웃 버거마저...무덤이 된 '기회의 땅' [지금이뉴스] https://n.news.naver.com/mnews/article/052/0002222821
# 42 “FBI의 킹 목사 감시, 암살 연루 정보는 발견되지 않아”-WP https://n.news.naver.com/mnews/article/003/0013377650
# 43 “대북 라디오 방송량 80% 줄어...北, 정보전서 중대한 승리” https://n.news.naver.com/mnews/article/009/0005529033
# 44 미·필리핀 “상호방위조약, 태평양 어디서든 적용”…관세협상도 잘 풀릴까 https://n.news.naver.com/mnews/article/025/0003456814
# 45 美재무 "8월 1일까지 합의하는 것보다 질 높은 무역 합의에 더 관심" https://n.news.naver.com/mnews/article/014/0005380649
# 46 '일본인 퍼스트' 참정당 돌풍... 일본에도 극우 물결? https://n.news.naver.com/mnews/article/047/0002481892

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=747269&no=247&week=wed',
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }

img_urls =[
    'https://image-comic.pstatic.net/webtoon/747269/247/20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/747269/247/20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/747269/247/20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers = req_header)   
    print(res.ok, res.status_code)  
    if res.ok:
        # binary 응답 데이터 가져오기
        img_data = res.content
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        print(file_name)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# True 200
# 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_1.jpg
# Writing to 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_1.jpg (171,780 bytes)
# True 200
# 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_2.jpg
# Writing to 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_2.jpg (164,843 bytes)
# True 200
# 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_3.jpg
# Writing to 20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_3.jpg (135,302 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=747269&no=247&week=wed'
req_header = {
    'referer':webtoon_url,
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }

res = requests.get(webtoon_url)
print(res.status_code)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    #print(len(soup.select("img[src $= '.jpg']")))
   # print(len(soup.select("img[src ^= 'https://image-comic.pstatic.net/webtoon/747269/247']")))
    print(len(soup.select("img[src*='IMAG01']")))
    # img src file명을 저장할 list선언
    img_url_list = list() #['http://xxx/aa.jpg']
    img_tags = soup.select("img[src*='IMAG01']")
    for img_tag in img_tags:
        img_url = img_tag['src']
        img_url_list.append(img_url)
    print(len(img_url_list), img_url_list[0:2])    

    #img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for jpg_url in img_url_list:
        res = requests.get(jpg_url, headers = req_header)
        if res.ok:
            # binary data 추출하기
            img_data = res.content
            #img/xxx.jpg 디렉토리명과 jpg 파일명을 join
            dir_name = os.path.join(imgdir_name, os.path.basename(jpg_url))
            with open(dir_name,'wb') as file:
                print(f'Writing to {dir_name}({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error Code = {res.status_code}')
# Out:
# 200
# 73
# 73 ['https://image-comic.pstatic.net/webtoon/747269/247/20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/747269/247/20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_2.jpg']
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_1.jpg(171,780 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_2.jpg(164,843 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_3.jpg(135,302 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_4.jpg(191,407 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_5.jpg(142,606 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_6.jpg(169,640 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_7.jpg(170,810 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_8.jpg(193,695 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_9.jpg(109,615 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_10.jpg(161,983 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_11.jpg(139,015 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_12.jpg(147,306 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_13.jpg(128,725 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_14.jpg(130,822 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_15.jpg(136,548 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_16.jpg(184,246 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_17.jpg(118,524 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_18.jpg(140,294 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_19.jpg(237,598 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_20.jpg(193,507 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_21.jpg(185,030 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_22.jpg(151,511 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_23.jpg(174,928 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_24.jpg(153,890 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_25.jpg(152,497 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_26.jpg(120,889 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_27.jpg(143,800 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_28.jpg(139,683 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_29.jpg(76,508 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_30.jpg(136,105 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_31.jpg(174,894 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_32.jpg(163,774 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_33.jpg(166,127 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_34.jpg(182,007 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_35.jpg(112,243 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_36.jpg(219,137 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_37.jpg(130,301 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_38.jpg(166,990 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_39.jpg(189,197 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_40.jpg(86,756 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_41.jpg(177,295 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_42.jpg(105,966 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_43.jpg(160,731 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_44.jpg(169,516 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_45.jpg(103,878 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_46.jpg(162,947 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_47.jpg(148,483 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_48.jpg(234,192 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_49.jpg(199,090 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_50.jpg(151,620 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_51.jpg(131,287 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_52.jpg(86,182 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_53.jpg(247,136 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_54.jpg(182,885 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_55.jpg(176,454 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_56.jpg(156,863 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_57.jpg(132,237 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_58.jpg(144,808 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_59.jpg(132,300 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_60.jpg(169,922 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_61.jpg(160,314 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_62.jpg(230,934 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_63.jpg(137,264 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_64.jpg(200,696 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_65.jpg(212,300 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_66.jpg(188,496 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_67.jpg(285,175 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_68.jpg(347,833 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_69.jpg(276,233 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_70.jpg(215,469 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_71.jpg(356,367 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_72.jpg(114,859 bytes)
# Writing to img\20250121111540_28a7695d95c59a2457c9b6e8fdc399b2_IMAG01_73.jpg(14,705 bytes)

# %% [markdown]
# #리펙토링코드
#
# import requests
# from bs4 import BeautifulSoup
# import os
#
# # 기본 설정
# url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
# req_header = {'referer': url}
# imgdir_name = 'img'
#
# # 이미지 저장 폴더가 없으면 생성
# os.makedirs(imgdir_name, exist_ok=True)
#
# # 웹 페이지 요청 및 확인
# res = requests.get(url)
# if not res.ok:
#     print(f'Error Code = {res.status_code}')
#     exit()
#
# # 이미지 URL 추출
# soup = BeautifulSoup(res.text, 'html.parser')
# img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]
#
# # 이미지 다운로드
# for img_url in img_url_list:
#     res = requests.get(img_url, headers=req_header)
#     if res.ok:
#         img_data = res.content
#         file_path = os.path.join(imgdir_name, os.path.basename(img_url))
#         with open(file_path, 'wb') as file:
#             print(f'Writing to {file_path} ({len(img_data):,} bytes)')
#             file.write(img_data)
#     else:
#         print(f'Error Code = {res.status_code} for {img_url}')

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('f1.jpg','rb'),
    'img2': open('f2.jpg','rb')
}
print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url,files=upload_files)
print(res.status_code)
print(res.json())
print(res.json()['files']['img1'])
# Out:
# {'img1': <_io.BufferedReader name='f1.jpg'>, 'img2': <_io.BufferedReader name='f2.jpg'>}
# 200
# {'args': {}, 'data': '', 'files': {'img1': 'data:application/octet-stream;base64,...', 'img2': 'data:application/octet-stream;base64,...'}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Content-Length': '336869', 'Content-Type': 'multipart/form-data; boundary=04cf7098a32f0773093fab6b031930b4', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-68804519-40c8d53f1af9eef155da20fa'}, 'json': None, 'origin': '1.224.58.231', 'url': 'http://httpbin.org/post'}
# data:application/octet-stream;base64,...

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
