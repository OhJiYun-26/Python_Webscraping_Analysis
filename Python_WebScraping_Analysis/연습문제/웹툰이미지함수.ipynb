# %%
import requests
from bs4 import BeautifulSoup
import os

def download_one_episode(title, no, url):
    # 이미지 저장 경로 생성: img/제목/회차번호/
    imgdir_name = os.path.join('img', str(title), str(no))
    if not os.path.isdir(imgdir_name):
        os.makedirs(imgdir_name, exist_ok=True)

    # referer, user-agent 헤더
    req_header = {
        'referer': url,
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }

    res = requests.get(url, headers=req_header)
    res.encoding = "utf-8"
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        # 웹툰 이미지는 src에 'IMAG01'이 포함되어 있음
        img_tags = soup.select("img[src*='IMAG01']")
        img_url_list = [img_tag['src'] for img_tag in img_tags]
        
        if not img_url_list:
            print("❌ 이미지가 없습니다!")
            return

        for idx, jpg_url in enumerate(img_url_list, 1):
            img_res = requests.get(jpg_url, headers=req_header)
            if img_res.ok:
                img_data = img_res.content
                # 파일명: 001.jpg, 002.jpg ...
                filename = f"{idx:03d}.jpg"
                file_path = os.path.join(imgdir_name, filename)
                with open(file_path, 'wb') as file:
                    print(f'Writing to {file_path} ({len(img_data):,} bytes)')
                    file.write(img_data)
            else:
                print(f'Error Code = {img_res.status_code}')
    else:
        print(f'Error Code = {res.status_code}')

# %%
download_one_episode(
    '전지적독자시점',
    247,
    'https://comic.naver.com/webtoon/detail?titleId=747269&no=247&week=wed'
)
# Out:
# Writing to img\전지적독자시점\247\001.jpg (171,780 bytes)
# Writing to img\전지적독자시점\247\002.jpg (164,843 bytes)
# Writing to img\전지적독자시점\247\003.jpg (135,302 bytes)
# Writing to img\전지적독자시점\247\004.jpg (191,407 bytes)
# Writing to img\전지적독자시점\247\005.jpg (142,606 bytes)
# Writing to img\전지적독자시점\247\006.jpg (169,640 bytes)
# Writing to img\전지적독자시점\247\007.jpg (170,810 bytes)
# Writing to img\전지적독자시점\247\008.jpg (193,695 bytes)
# Writing to img\전지적독자시점\247\009.jpg (109,615 bytes)
# Writing to img\전지적독자시점\247\010.jpg (161,983 bytes)
# Writing to img\전지적독자시점\247\011.jpg (139,015 bytes)
# Writing to img\전지적독자시점\247\012.jpg (147,306 bytes)
# Writing to img\전지적독자시점\247\013.jpg (128,725 bytes)
# Writing to img\전지적독자시점\247\014.jpg (130,822 bytes)
# Writing to img\전지적독자시점\247\015.jpg (136,548 bytes)
# Writing to img\전지적독자시점\247\016.jpg (184,246 bytes)
# Writing to img\전지적독자시점\247\017.jpg (118,524 bytes)
# Writing to img\전지적독자시점\247\018.jpg (140,294 bytes)
# Writing to img\전지적독자시점\247\019.jpg (237,598 bytes)
# Writing to img\전지적독자시점\247\020.jpg (193,507 bytes)
# Writing to img\전지적독자시점\247\021.jpg (185,030 bytes)
# Writing to img\전지적독자시점\247\022.jpg (151,511 bytes)
# Writing to img\전지적독자시점\247\023.jpg (174,928 bytes)
# Writing to img\전지적독자시점\247\024.jpg (153,890 bytes)
# Writing to img\전지적독자시점\247\025.jpg (152,497 bytes)
# Writing to img\전지적독자시점\247\026.jpg (120,889 bytes)
# Writing to img\전지적독자시점\247\027.jpg (143,800 bytes)
# Writing to img\전지적독자시점\247\028.jpg (139,683 bytes)
# Writing to img\전지적독자시점\247\029.jpg (76,508 bytes)
# Writing to img\전지적독자시점\247\030.jpg (136,105 bytes)
# Writing to img\전지적독자시점\247\031.jpg (174,894 bytes)
# Writing to img\전지적독자시점\247\032.jpg (163,774 bytes)
# Writing to img\전지적독자시점\247\033.jpg (166,127 bytes)
# Writing to img\전지적독자시점\247\034.jpg (182,007 bytes)
# Writing to img\전지적독자시점\247\035.jpg (112,243 bytes)
# Writing to img\전지적독자시점\247\036.jpg (219,137 bytes)
# Writing to img\전지적독자시점\247\037.jpg (130,301 bytes)
# Writing to img\전지적독자시점\247\038.jpg (166,990 bytes)
# Writing to img\전지적독자시점\247\039.jpg (189,197 bytes)
# Writing to img\전지적독자시점\247\040.jpg (86,756 bytes)
# Writing to img\전지적독자시점\247\041.jpg (177,295 bytes)
# Writing to img\전지적독자시점\247\042.jpg (105,966 bytes)
# Writing to img\전지적독자시점\247\043.jpg (160,731 bytes)
# Writing to img\전지적독자시점\247\044.jpg (169,516 bytes)
# Writing to img\전지적독자시점\247\045.jpg (103,878 bytes)
# Writing to img\전지적독자시점\247\046.jpg (162,947 bytes)
# Writing to img\전지적독자시점\247\047.jpg (148,483 bytes)
# Writing to img\전지적독자시점\247\048.jpg (234,192 bytes)
# Writing to img\전지적독자시점\247\049.jpg (199,090 bytes)
# Writing to img\전지적독자시점\247\050.jpg (151,620 bytes)
# Writing to img\전지적독자시점\247\051.jpg (131,287 bytes)
# Writing to img\전지적독자시점\247\052.jpg (86,182 bytes)
# Writing to img\전지적독자시점\247\053.jpg (247,136 bytes)
# Writing to img\전지적독자시점\247\054.jpg (182,885 bytes)
# Writing to img\전지적독자시점\247\055.jpg (176,454 bytes)
# Writing to img\전지적독자시점\247\056.jpg (156,863 bytes)
# Writing to img\전지적독자시점\247\057.jpg (132,237 bytes)
# Writing to img\전지적독자시점\247\058.jpg (144,808 bytes)
# Writing to img\전지적독자시점\247\059.jpg (132,300 bytes)
# Writing to img\전지적독자시점\247\060.jpg (169,922 bytes)
# Writing to img\전지적독자시점\247\061.jpg (160,314 bytes)
# Writing to img\전지적독자시점\247\062.jpg (230,934 bytes)
# Writing to img\전지적독자시점\247\063.jpg (137,264 bytes)
# Writing to img\전지적독자시점\247\064.jpg (200,696 bytes)
# Writing to img\전지적독자시점\247\065.jpg (212,300 bytes)
# Writing to img\전지적독자시점\247\066.jpg (188,496 bytes)
# Writing to img\전지적독자시점\247\067.jpg (285,175 bytes)
# Writing to img\전지적독자시점\247\068.jpg (347,833 bytes)
# Writing to img\전지적독자시점\247\069.jpg (276,233 bytes)
# Writing to img\전지적독자시점\247\070.jpg (215,469 bytes)
# Writing to img\전지적독자시점\247\071.jpg (356,367 bytes)
# Writing to img\전지적독자시점\247\072.jpg (114,859 bytes)
# Writing to img\전지적독자시점\247\073.jpg (14,705 bytes)
